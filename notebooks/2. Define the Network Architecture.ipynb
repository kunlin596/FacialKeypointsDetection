# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### Define your model in the provided file `models.py` file
# ```py
# Net(
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (conv4): Conv2d(128, 256, kernel_size=(2, 2), stride=(1, 1))
#   (dropout4): Dropout(p=0.4, inplace=False)
#   (fc1): Linear(in_features=36864, out_features=1000, bias=True)
#   (dropout5): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=1000, out_features=1000, bias=True)
#   (dropout6): Dropout(p=0.6, inplace=False)
#   (fc3): Linear(in_features=1000, out_features=136, bias=True)
# )
# ```
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

data_root = Path(".")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from facial_keypoints_detection import models

net = models.Net()
print(net)
# Out:
# Net(
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (conv4): Conv2d(128, 256, kernel_size=(2, 2), stride=(1, 1))
#   (dropout4): Dropout(p=0.4, inplace=False)
#   (fc1): Linear(in_features=36864, out_features=1000, bias=True)
#   (dropout5): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=1000, out_features=1000, bias=True)
#   (dropout6): Dropout(p=0.6, inplace=False)
#   (fc3): Linear(in_features=1000, out_features=136, bias=True)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from facial_keypoints_detection.data import FacialKeypointsDataset

# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from facial_keypoints_detection.data import Transformer


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose(
    [
        Transformer.Rescale(250),
        Transformer.RandomCrop(224),
        Transformer.Normalize(),
        Transformer.ToTensor(),
    ]
)

# testing that you've defined a transform
assert data_transform is not None, "Define a data_transform"

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(
    csv_file=data_root / "data/training_frames_keypoints.csv",
    root_dir=data_root / "data/training/",
    transform=data_transform,
)

print("Number of images: ", len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample["image"].size(), sample["keypoints"].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 10

train_loader = DataLoader(
    transformed_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=4,
)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(
    csv_file=data_root / "data/test_frames_keypoints.csv",
    root_dir=data_root / "data/test/",
    transform=data_transform,
)

# %%
# load test data in batches
batch_size = 10

test_loader = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=True, num_workers=4
)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images
def net_sample_output():
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        # get sample data: images and ground truth keypoints
        images = sample["image"]
        key_pts = sample["keypoints"]

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor)

        # forward pass to get net output
        output_pts = net(images)

        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)

        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap="gray")
    plt.scatter(
        predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=10, marker=".", c="m"
    )
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=10, marker=".", c="g")

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(40, 30))
        ax = plt.subplot(1, batch_size, i + 1)

        # un-transform the image data
        image = test_images[i].data  # get the image from it's wrapper
        image = image.numpy()  # convert to numpy array from a Tensor
        image = np.transpose(
            image, (1, 2, 0)
        )  # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints
        predicted_key_pts = predicted_key_pts * 50.0 + 100

        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]
            ground_truth_pts = ground_truth_pts * 50.0 + 100

        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)

        plt.axis("off")

    plt.show()


# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
import torch.optim as optim

if torch.has_cuda:
    criterion = nn.MSELoss().cuda()
elif torch.has_mps:
    criterion = nn.MSELoss().to('mps')
else:
    criterion = nn.MSELoss()

optimizer = optim.Adam(net.parameters(), lr=1e-4)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
import time

def train_net(n_epochs):
    # prepare the net for training
    if torch.has_cuda:
        net.to("cuda")
        print("Sending model to CUDA.")
    elif torch.has_mps:
        net.to("mps")
        print("Sending model to MPS.")
    net.train()

    batch_loss = []
    start_time = time.time()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        running_loss = 0.0
        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data["image"]
            key_pts = data["keypoints"]

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            if torch.has_cuda:
                key_pts = key_pts.type(torch.FloatTensor).cuda()
                images = images.type(torch.FloatTensor).cuda()
            elif torch.has_mps:
                key_pts = key_pts.type(torch.FloatTensor).to("mps")
                images = images.type(torch.FloatTensor).to("mps")
            else:
                key_pts = key_pts.type(torch.FloatTensor)
                images = images.type(torch.FloatTensor)

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()

            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()

            # print every 10 batches
            if batch_i % 10 == 9:
                print(
                    f"Epoch: {epoch + 1:3}, Batch: {batch_i + 1:5}, "
                    f"Avg. Loss: {running_loss / 1000.0:11.10f} "
                    f"Elapsed Time: {time.time() - start_time:3.3} seconds."
                )
                batch_loss.append(running_loss)
                start_time = time.time()
                running_loss = 0.0

    print("Finished Training")
    return batch_loss

# %%
# train your network
# start small, and increase when you've decided on your model structure and hyper parameters
n_epochs = 10
batch_loss = train_net(n_epochs)
# Out:
# Sending model to MPS.
# Epoch:   1, Batch:    10, Avg. Loss: 0.0057756672 Elapsed Time: 4.78 seconds.
# Epoch:   1, Batch:    20, Avg. Loss: 0.0035974681 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:    30, Avg. Loss: 0.0024579440 Elapsed Time: 1.87 seconds.
# Epoch:   1, Batch:    40, Avg. Loss: 0.0024643987 Elapsed Time: 1.77 seconds.
# Epoch:   1, Batch:    50, Avg. Loss: 0.0028398784 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:    60, Avg. Loss: 0.0023891306 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:    70, Avg. Loss: 0.0020639135 Elapsed Time: 1.76 seconds.
# Epoch:   1, Batch:    80, Avg. Loss: 0.0019833448 Elapsed Time: 1.77 seconds.
# Epoch:   1, Batch:    90, Avg. Loss: 0.0022144813 Elapsed Time: 1.83 seconds.
# Epoch:   1, Batch:   100, Avg. Loss: 0.0025996476 Elapsed Time: 1.88 seconds.
# Epoch:   1, Batch:   110, Avg. Loss: 0.0024664973 Elapsed Time: 1.86 seconds.
# Epoch:   1, Batch:   120, Avg. Loss: 0.0023348296 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:   130, Avg. Loss: 0.0021428546 Elapsed Time: 1.87 seconds.
# Epoch:   1, Batch:   140, Avg. Loss: 0.0020036201 Elapsed Time: 1.84 seconds.
# Epoch:   1, Batch:   150, Avg. Loss: 0.0023930299 Elapsed Time: 1.86 seconds.
# Epoch:   1, Batch:   160, Avg. Loss: 0.0019961001 Elapsed Time: 1.84 seconds.
# Epoch:   1, Batch:   170, Avg. Loss: 0.0016989724 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:   180, Avg. Loss: 0.0020116412 Elapsed Time: 1.8 seconds.
# Epoch:   1, Batch:   190, Avg. Loss: 0.0019775277 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:   200, Avg. Loss: 0.0017169891 Elapsed Time: 1.75 seconds.
# Epoch:   1, Batch:   210, Avg. Loss: 0.0018649300 Elapsed Time: 1.79 seconds.
# Epoch:   1, Batch:   220, Avg. Loss: 0.0027164249 Elapsed Time: 1.72 seconds.
# Epoch:   1, Batch:   230, Avg. Loss: 0.0020001914 Elapsed Time: 1.83 seconds.
# Epoch:   1, Batch:   240, Avg. Loss: 0.0021249374 Elapsed Time: 1.73 seconds.
# Epoch:   1, Batch:   250, Avg. Loss: 0.0022890943 Elapsed Time: 1.8 seconds.
# Epoch:   1, Batch:   260, Avg. Loss: 0.0020815488 Elapsed Time: 1.8 seconds.
# Epoch:   1, Batch:   270, Avg. Loss: 0.0024403476 Elapsed Time: 1.81 seconds.
# Epoch:   1, Batch:   280, Avg. Loss: 0.0019859171 Elapsed Time: 1.79 seconds.
# Epoch:   1, Batch:   290, Avg. Loss: 0.0019200875 Elapsed Time: 1.77 seconds.
# Epoch:   1, Batch:   300, Avg. Loss: 0.0017740775 Elapsed Time: 1.79 seconds.
# Epoch:   1, Batch:   310, Avg. Loss: 0.0017514116 Elapsed Time: 1.82 seconds.
# Epoch:   1, Batch:   320, Avg. Loss: 0.0018206122 Elapsed Time: 1.79 seconds.
# Epoch:   1, Batch:   330, Avg. Loss: 0.0021037409 Elapsed Time: 1.78 seconds.
# Epoch:   1, Batch:   340, Avg. Loss: 0.0019922669 Elapsed Time: 1.8 seconds.
# Epoch:   2, Batch:    10, Avg. Loss: 0.0014645781 Elapsed Time: 25.9 seconds.
# Epoch:   2, Batch:    20, Avg. Loss: 0.0020211596 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:    30, Avg. Loss: 0.0020253504 Elapsed Time: 1.76 seconds.
# Epoch:   2, Batch:    40, Avg. Loss: 0.0024892629 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:    50, Avg. Loss: 0.0017812404 Elapsed Time: 1.73 seconds.
# Epoch:   2, Batch:    60, Avg. Loss: 0.0016541596 Elapsed Time: 1.78 seconds.
# Epoch:   2, Batch:    70, Avg. Loss: 0.0022808872 Elapsed Time: 1.73 seconds.
# Epoch:   2, Batch:    80, Avg. Loss: 0.0018817659 Elapsed Time: 1.75 seconds.
# Epoch:   2, Batch:    90, Avg. Loss: 0.0025999354 Elapsed Time: 1.78 seconds.
# Epoch:   2, Batch:   100, Avg. Loss: 0.0018673813 Elapsed Time: 1.78 seconds.
# Epoch:   2, Batch:   110, Avg. Loss: 0.0018681591 Elapsed Time: 1.77 seconds.
# Epoch:   2, Batch:   120, Avg. Loss: 0.0020354697 Elapsed Time: 1.73 seconds.
# Epoch:   2, Batch:   130, Avg. Loss: 0.0019456352 Elapsed Time: 1.75 seconds.
# Epoch:   2, Batch:   140, Avg. Loss: 0.0016493380 Elapsed Time: 1.75 seconds.
# Epoch:   2, Batch:   150, Avg. Loss: 0.0017878993 Elapsed Time: 1.81 seconds.
# Epoch:   2, Batch:   160, Avg. Loss: 0.0017492750 Elapsed Time: 1.78 seconds.
# Epoch:   2, Batch:   170, Avg. Loss: 0.0023455069 Elapsed Time: 1.89 seconds.
# Epoch:   2, Batch:   180, Avg. Loss: 0.0021510800 Elapsed Time: 1.79 seconds.
# Epoch:   2, Batch:   190, Avg. Loss: 0.0021346559 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:   200, Avg. Loss: 0.0018311902 Elapsed Time: 1.78 seconds.
# Epoch:   2, Batch:   210, Avg. Loss: 0.0020589039 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:   220, Avg. Loss: 0.0018114189 Elapsed Time: 1.75 seconds.
# Epoch:   2, Batch:   230, Avg. Loss: 0.0019013486 Elapsed Time: 1.76 seconds.
# Epoch:   2, Batch:   240, Avg. Loss: 0.0020719294 Elapsed Time: 1.75 seconds.
# Epoch:   2, Batch:   250, Avg. Loss: 0.0017856659 Elapsed Time: 1.7 seconds.
# Epoch:   2, Batch:   260, Avg. Loss: 0.0017181546 Elapsed Time: 1.73 seconds.
# Epoch:   2, Batch:   270, Avg. Loss: 0.0019540878 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:   280, Avg. Loss: 0.0017308572 Elapsed Time: 1.73 seconds.
# Epoch:   2, Batch:   290, Avg. Loss: 0.0019869105 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:   300, Avg. Loss: 0.0022721940 Elapsed Time: 1.71 seconds.
# Epoch:   2, Batch:   310, Avg. Loss: 0.0020201182 Elapsed Time: 1.71 seconds.
# Epoch:   2, Batch:   320, Avg. Loss: 0.0018111220 Elapsed Time: 1.72 seconds.
# Epoch:   2, Batch:   330, Avg. Loss: 0.0025229002 Elapsed Time: 1.7 seconds.
# Epoch:   2, Batch:   340, Avg. Loss: 0.0022037956 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:    10, Avg. Loss: 0.0018548537 Elapsed Time: 25.5 seconds.
# Epoch:   3, Batch:    20, Avg. Loss: 0.0019844974 Elapsed Time: 1.7 seconds.
# Epoch:   3, Batch:    30, Avg. Loss: 0.0020301995 Elapsed Time: 1.7 seconds.
# Epoch:   3, Batch:    40, Avg. Loss: 0.0020310931 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:    50, Avg. Loss: 0.0018016247 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:    60, Avg. Loss: 0.0021660267 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:    70, Avg. Loss: 0.0023645678 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:    80, Avg. Loss: 0.0020911871 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:    90, Avg. Loss: 0.0017446280 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:   100, Avg. Loss: 0.0021563591 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:   110, Avg. Loss: 0.0017897812 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:   120, Avg. Loss: 0.0017866430 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:   130, Avg. Loss: 0.0021611171 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:   140, Avg. Loss: 0.0020184962 Elapsed Time: 1.7 seconds.
# Epoch:   3, Batch:   150, Avg. Loss: 0.0020890155 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:   160, Avg. Loss: 0.0019144003 Elapsed Time: 1.73 seconds.
# Epoch:   3, Batch:   170, Avg. Loss: 0.0033925945 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:   180, Avg. Loss: 0.0014390026 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:   190, Avg. Loss: 0.0018555838 Elapsed Time: 1.7 seconds.
# Epoch:   3, Batch:   200, Avg. Loss: 0.0017276478 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:   210, Avg. Loss: 0.0021554000 Elapsed Time: 1.7 seconds.
# Epoch:   3, Batch:   220, Avg. Loss: 0.0018344735 Elapsed Time: 1.74 seconds.
# Epoch:   3, Batch:   230, Avg. Loss: 0.0021337459 Elapsed Time: 1.71 seconds.
# Epoch:   3, Batch:   240, Avg. Loss: 0.0024070499 Elapsed Time: 1.72 seconds.
# Epoch:   3, Batch:   250, Avg. Loss: 0.0019198007 Elapsed Time: 1.75 seconds.
# Epoch:   3, Batch:   260, Avg. Loss: 0.0019901719 Elapsed Time: 1.9 seconds.
# Epoch:   3, Batch:   270, Avg. Loss: 0.0021894201 Elapsed Time: 1.9 seconds.
# Epoch:   3, Batch:   280, Avg. Loss: 0.0020208743 Elapsed Time: 1.8 seconds.
# Epoch:   3, Batch:   290, Avg. Loss: 0.0022166539 Elapsed Time: 1.99 seconds.
# Epoch:   3, Batch:   300, Avg. Loss: 0.0017525305 Elapsed Time: 1.82 seconds.
# Epoch:   3, Batch:   310, Avg. Loss: 0.0022502870 Elapsed Time: 1.8 seconds.
# Epoch:   3, Batch:   320, Avg. Loss: 0.0017006017 Elapsed Time: 1.77 seconds.
# Epoch:   3, Batch:   330, Avg. Loss: 0.0019332837 Elapsed Time: 1.74 seconds.
# Epoch:   3, Batch:   340, Avg. Loss: 0.0017174995 Elapsed Time: 1.72 seconds.
# Epoch:   4, Batch:    10, Avg. Loss: 0.0019790016 Elapsed Time: 25.9 seconds.
# Epoch:   4, Batch:    20, Avg. Loss: 0.0018288310 Elapsed Time: 1.84 seconds.
# Epoch:   4, Batch:    30, Avg. Loss: 0.0021377873 Elapsed Time: 1.83 seconds.
# Epoch:   4, Batch:    40, Avg. Loss: 0.0019423504 Elapsed Time: 1.92 seconds.
# Epoch:   4, Batch:    50, Avg. Loss: 0.0018766116 Elapsed Time: 1.88 seconds.
# Epoch:   4, Batch:    60, Avg. Loss: 0.0018604721 Elapsed Time: 1.87 seconds.
# Epoch:   4, Batch:    70, Avg. Loss: 0.0021018422 Elapsed Time: 1.9 seconds.
# Epoch:   4, Batch:    80, Avg. Loss: 0.0019019517 Elapsed Time: 2.06 seconds.
# Epoch:   4, Batch:    90, Avg. Loss: 0.0017525287 Elapsed Time: 1.89 seconds.
# Epoch:   4, Batch:   100, Avg. Loss: 0.0018402293 Elapsed Time: 1.87 seconds.
# Epoch:   4, Batch:   110, Avg. Loss: 0.0018012748 Elapsed Time: 1.84 seconds.
# Epoch:   4, Batch:   120, Avg. Loss: 0.0019958111 Elapsed Time: 1.91 seconds.
# Epoch:   4, Batch:   130, Avg. Loss: 0.0018563896 Elapsed Time: 2.01 seconds.
# Epoch:   4, Batch:   140, Avg. Loss: 0.0020898563 Elapsed Time: 1.92 seconds.
# Epoch:   4, Batch:   150, Avg. Loss: 0.0015715879 Elapsed Time: 1.86 seconds.
# Epoch:   4, Batch:   160, Avg. Loss: 0.0019127533 Elapsed Time: 1.85 seconds.
# Epoch:   4, Batch:   170, Avg. Loss: 0.0021780417 Elapsed Time: 1.81 seconds.
# Epoch:   4, Batch:   180, Avg. Loss: 0.0021690197 Elapsed Time: 1.81 seconds.
# Epoch:   4, Batch:   190, Avg. Loss: 0.0020982913 Elapsed Time: 1.8 seconds.
# Epoch:   4, Batch:   200, Avg. Loss: 0.0018490232 Elapsed Time: 1.77 seconds.
# Epoch:   4, Batch:   210, Avg. Loss: 0.0019974421 Elapsed Time: 1.79 seconds.
# Epoch:   4, Batch:   220, Avg. Loss: 0.0018893569 Elapsed Time: 1.85 seconds.
# Epoch:   4, Batch:   230, Avg. Loss: 0.0023875505 Elapsed Time: 1.83 seconds.
# Epoch:   4, Batch:   240, Avg. Loss: 0.0017868219 Elapsed Time: 1.78 seconds.
# Epoch:   4, Batch:   250, Avg. Loss: 0.0022289649 Elapsed Time: 1.77 seconds.
# Epoch:   4, Batch:   260, Avg. Loss: 0.0018899577 Elapsed Time: 1.79 seconds.
# Epoch:   4, Batch:   270, Avg. Loss: 0.0022043437 Elapsed Time: 1.82 seconds.
# Epoch:   4, Batch:   280, Avg. Loss: 0.0022102880 Elapsed Time: 1.83 seconds.
# Epoch:   4, Batch:   290, Avg. Loss: 0.0016480753 Elapsed Time: 1.89 seconds.
# Epoch:   4, Batch:   300, Avg. Loss: 0.0018307407 Elapsed Time: 1.88 seconds.
# Epoch:   4, Batch:   310, Avg. Loss: 0.0022716561 Elapsed Time: 1.96 seconds.
# Epoch:   4, Batch:   320, Avg. Loss: 0.0018911218 Elapsed Time: 1.94 seconds.
# Epoch:   4, Batch:   330, Avg. Loss: 0.0019268471 Elapsed Time: 1.93 seconds.
# Epoch:   4, Batch:   340, Avg. Loss: 0.0019691342 Elapsed Time: 1.93 seconds.
# Epoch:   5, Batch:    10, Avg. Loss: 0.0016173479 Elapsed Time: 26.3 seconds.
# Epoch:   5, Batch:    20, Avg. Loss: 0.0022101555 Elapsed Time: 1.82 seconds.
# Epoch:   5, Batch:    30, Avg. Loss: 0.0017726106 Elapsed Time: 1.84 seconds.
# Epoch:   5, Batch:    40, Avg. Loss: 0.0017028588 Elapsed Time: 1.78 seconds.
# Epoch:   5, Batch:    50, Avg. Loss: 0.0019007165 Elapsed Time: 1.83 seconds.
# Epoch:   5, Batch:    60, Avg. Loss: 0.0021408362 Elapsed Time: 1.79 seconds.
# Epoch:   5, Batch:    70, Avg. Loss: 0.0016400010 Elapsed Time: 1.84 seconds.
# Epoch:   5, Batch:    80, Avg. Loss: 0.0019422964 Elapsed Time: 1.92 seconds.
# Epoch:   5, Batch:    90, Avg. Loss: 0.0018006608 Elapsed Time: 1.89 seconds.
# Epoch:   5, Batch:   100, Avg. Loss: 0.0019595473 Elapsed Time: 1.98 seconds.
# Epoch:   5, Batch:   110, Avg. Loss: 0.0019985332 Elapsed Time: 1.92 seconds.
# Epoch:   5, Batch:   120, Avg. Loss: 0.0015750349 Elapsed Time: 1.98 seconds.
# Epoch:   5, Batch:   130, Avg. Loss: 0.0021635664 Elapsed Time: 2.08 seconds.
# Epoch:   5, Batch:   140, Avg. Loss: 0.0017778502 Elapsed Time: 2.12 seconds.
# Epoch:   5, Batch:   150, Avg. Loss: 0.0024307231 Elapsed Time: 2.08 seconds.
# Epoch:   5, Batch:   160, Avg. Loss: 0.0022617649 Elapsed Time: 2.08 seconds.
# Epoch:   5, Batch:   170, Avg. Loss: 0.0018354837 Elapsed Time: 1.98 seconds.
# Epoch:   5, Batch:   180, Avg. Loss: 0.0017254888 Elapsed Time: 2.0 seconds.
# Epoch:   5, Batch:   190, Avg. Loss: 0.0022642971 Elapsed Time: 1.98 seconds.
# Epoch:   5, Batch:   200, Avg. Loss: 0.0021090077 Elapsed Time: 1.96 seconds.
# Epoch:   5, Batch:   210, Avg. Loss: 0.0019930158 Elapsed Time: 1.91 seconds.
# Epoch:   5, Batch:   220, Avg. Loss: 0.0021184387 Elapsed Time: 1.94 seconds.
# Epoch:   5, Batch:   230, Avg. Loss: 0.0020150167 Elapsed Time: 1.92 seconds.
# Epoch:   5, Batch:   240, Avg. Loss: 0.0021335581 Elapsed Time: 1.89 seconds.
# Epoch:   5, Batch:   250, Avg. Loss: 0.0026836293 Elapsed Time: 1.9 seconds.
# Epoch:   5, Batch:   260, Avg. Loss: 0.0027719196 Elapsed Time: 1.92 seconds.
# Epoch:   5, Batch:   270, Avg. Loss: 0.0016058928 Elapsed Time: 1.93 seconds.
# Epoch:   5, Batch:   280, Avg. Loss: 0.0023592478 Elapsed Time: 1.95 seconds.
# Epoch:   5, Batch:   290, Avg. Loss: 0.0024862236 Elapsed Time: 1.97 seconds.
# Epoch:   5, Batch:   300, Avg. Loss: 0.0021027250 Elapsed Time: 1.88 seconds.
# Epoch:   5, Batch:   310, Avg. Loss: 0.0020347258 Elapsed Time: 1.9 seconds.
# Epoch:   5, Batch:   320, Avg. Loss: 0.0018152786 Elapsed Time: 1.89 seconds.
# Epoch:   5, Batch:   330, Avg. Loss: 0.0021514387 Elapsed Time: 1.87 seconds.
# Epoch:   5, Batch:   340, Avg. Loss: 0.0019012228 Elapsed Time: 1.88 seconds.
# Epoch:   6, Batch:    10, Avg. Loss: 0.0023893808 Elapsed Time: 25.8 seconds.
# Epoch:   6, Batch:    20, Avg. Loss: 0.0019515601 Elapsed Time: 2.0 seconds.
# Epoch:   6, Batch:    30, Avg. Loss: 0.0020273607 Elapsed Time: 2.03 seconds.
# Epoch:   6, Batch:    40, Avg. Loss: 0.0022147864 Elapsed Time: 1.9 seconds.
# Epoch:   6, Batch:    50, Avg. Loss: 0.0016988937 Elapsed Time: 1.89 seconds.
# Epoch:   6, Batch:    60, Avg. Loss: 0.0025266642 Elapsed Time: 2.02 seconds.
# Epoch:   6, Batch:    70, Avg. Loss: 0.0016408397 Elapsed Time: 1.94 seconds.
# Epoch:   6, Batch:    80, Avg. Loss: 0.0022579038 Elapsed Time: 2.11 seconds.
# Epoch:   6, Batch:    90, Avg. Loss: 0.0017559683 Elapsed Time: 2.01 seconds.
# Epoch:   6, Batch:   100, Avg. Loss: 0.0016900008 Elapsed Time: 1.99 seconds.
# Epoch:   6, Batch:   110, Avg. Loss: 0.0017098695 Elapsed Time: 1.97 seconds.
# Epoch:   6, Batch:   120, Avg. Loss: 0.0023033252 Elapsed Time: 1.92 seconds.
# Epoch:   6, Batch:   130, Avg. Loss: 0.0021333092 Elapsed Time: 1.96 seconds.
# Epoch:   6, Batch:   140, Avg. Loss: 0.0018970513 Elapsed Time: 2.06 seconds.
# Epoch:   6, Batch:   150, Avg. Loss: 0.0015631186 Elapsed Time: 2.3 seconds.
# Epoch:   6, Batch:   160, Avg. Loss: 0.0018060174 Elapsed Time: 2.26 seconds.
# Epoch:   6, Batch:   170, Avg. Loss: 0.0017419759 Elapsed Time: 2.1 seconds.
# Epoch:   6, Batch:   180, Avg. Loss: 0.0017972766 Elapsed Time: 2.15 seconds.
# Epoch:   6, Batch:   190, Avg. Loss: 0.0016947741 Elapsed Time: 2.21 seconds.
# Epoch:   6, Batch:   200, Avg. Loss: 0.0020758720 Elapsed Time: 2.21 seconds.
# Epoch:   6, Batch:   210, Avg. Loss: 0.0021459125 Elapsed Time: 2.09 seconds.
# Epoch:   6, Batch:   220, Avg. Loss: 0.0017150973 Elapsed Time: 2.15 seconds.
# Epoch:   6, Batch:   230, Avg. Loss: 0.0021377306 Elapsed Time: 2.04 seconds.
# Epoch:   6, Batch:   240, Avg. Loss: 0.0017477609 Elapsed Time: 2.04 seconds.
# Epoch:   6, Batch:   250, Avg. Loss: 0.0020827719 Elapsed Time: 2.48 seconds.
# Epoch:   6, Batch:   260, Avg. Loss: 0.0020384547 Elapsed Time: 2.58 seconds.
# Epoch:   6, Batch:   270, Avg. Loss: 0.0018108282 Elapsed Time: 2.44 seconds.
# Epoch:   6, Batch:   280, Avg. Loss: 0.0019563970 Elapsed Time: 2.16 seconds.
# Epoch:   6, Batch:   290, Avg. Loss: 0.0016536476 Elapsed Time: 2.16 seconds.
# Epoch:   6, Batch:   300, Avg. Loss: 0.0017880624 Elapsed Time: 2.12 seconds.
# Epoch:   6, Batch:   310, Avg. Loss: 0.0022019372 Elapsed Time: 2.12 seconds.
# Epoch:   6, Batch:   320, Avg. Loss: 0.0017755135 Elapsed Time: 1.99 seconds.
# Epoch:   6, Batch:   330, Avg. Loss: 0.0021051586 Elapsed Time: 2.04 seconds.
# Epoch:   6, Batch:   340, Avg. Loss: 0.0022176820 Elapsed Time: 2.01 seconds.
# Epoch:   7, Batch:    10, Avg. Loss: 0.0017083970 Elapsed Time: 26.1 seconds.
# Epoch:   7, Batch:    20, Avg. Loss: 0.0019324593 Elapsed Time: 2.09 seconds.
# Epoch:   7, Batch:    30, Avg. Loss: 0.0023440827 Elapsed Time: 2.12 seconds.
# Epoch:   7, Batch:    40, Avg. Loss: 0.0018054024 Elapsed Time: 2.12 seconds.
# Epoch:   7, Batch:    50, Avg. Loss: 0.0020829930 Elapsed Time: 2.55 seconds.
# Epoch:   7, Batch:    60, Avg. Loss: 0.0016190355 Elapsed Time: 2.47 seconds.
# Epoch:   7, Batch:    70, Avg. Loss: 0.0019665912 Elapsed Time: 2.83 seconds.
# Epoch:   7, Batch:    80, Avg. Loss: 0.0015510387 Elapsed Time: 2.36 seconds.
# Epoch:   7, Batch:    90, Avg. Loss: 0.0017744409 Elapsed Time: 2.2 seconds.
# Epoch:   7, Batch:   100, Avg. Loss: 0.0017481589 Elapsed Time: 2.18 seconds.
# Epoch:   7, Batch:   110, Avg. Loss: 0.0024934603 Elapsed Time: 1.98 seconds.
# Epoch:   7, Batch:   120, Avg. Loss: 0.0016926485 Elapsed Time: 2.01 seconds.
# Epoch:   7, Batch:   130, Avg. Loss: 0.0015361315 Elapsed Time: 2.07 seconds.
# Epoch:   7, Batch:   140, Avg. Loss: 0.0017749745 Elapsed Time: 2.06 seconds.
# Epoch:   7, Batch:   150, Avg. Loss: 0.0020526640 Elapsed Time: 2.03 seconds.
# Epoch:   7, Batch:   160, Avg. Loss: 0.0020400398 Elapsed Time: 2.0 seconds.
# Epoch:   7, Batch:   170, Avg. Loss: 0.0017255783 Elapsed Time: 2.08 seconds.
# Epoch:   7, Batch:   180, Avg. Loss: 0.0021046040 Elapsed Time: 2.02 seconds.
# Epoch:   7, Batch:   190, Avg. Loss: 0.0015553675 Elapsed Time: 2.08 seconds.
# Epoch:   7, Batch:   200, Avg. Loss: 0.0020666139 Elapsed Time: 1.95 seconds.
# Epoch:   7, Batch:   210, Avg. Loss: 0.0022818273 Elapsed Time: 2.04 seconds.
# Epoch:   7, Batch:   220, Avg. Loss: 0.0016370249 Elapsed Time: 1.94 seconds.
# Epoch:   7, Batch:   230, Avg. Loss: 0.0019426057 Elapsed Time: 2.02 seconds.
# Epoch:   7, Batch:   240, Avg. Loss: 0.0016144259 Elapsed Time: 1.96 seconds.
# Epoch:   7, Batch:   250, Avg. Loss: 0.0023287141 Elapsed Time: 1.97 seconds.
# Epoch:   7, Batch:   260, Avg. Loss: 0.0020189960 Elapsed Time: 1.92 seconds.
# Epoch:   7, Batch:   270, Avg. Loss: 0.0018028693 Elapsed Time: 1.99 seconds.
# Epoch:   7, Batch:   280, Avg. Loss: 0.0019951660 Elapsed Time: 2.02 seconds.
# Epoch:   7, Batch:   290, Avg. Loss: 0.0020267296 Elapsed Time: 1.99 seconds.
# Epoch:   7, Batch:   300, Avg. Loss: 0.0026466605 Elapsed Time: 2.02 seconds.
# Epoch:   7, Batch:   310, Avg. Loss: 0.0018363853 Elapsed Time: 2.08 seconds.
# Epoch:   7, Batch:   320, Avg. Loss: 0.0019109496 Elapsed Time: 2.12 seconds.
# Epoch:   7, Batch:   330, Avg. Loss: 0.0019382394 Elapsed Time: 2.15 seconds.
# Epoch:   7, Batch:   340, Avg. Loss: 0.0019787150 Elapsed Time: 2.33 seconds.
# Epoch:   8, Batch:    10, Avg. Loss: 0.0015790523 Elapsed Time: 26.0 seconds.
# Epoch:   8, Batch:    20, Avg. Loss: 0.0017403613 Elapsed Time: 1.89 seconds.
# Epoch:   8, Batch:    30, Avg. Loss: 0.0019119008 Elapsed Time: 1.97 seconds.
# Epoch:   8, Batch:    40, Avg. Loss: 0.0018122511 Elapsed Time: 1.9 seconds.
# Epoch:   8, Batch:    50, Avg. Loss: 0.0027138556 Elapsed Time: 1.86 seconds.
# Epoch:   8, Batch:    60, Avg. Loss: 0.0019845833 Elapsed Time: 1.9 seconds.
# Epoch:   8, Batch:    70, Avg. Loss: 0.0017348534 Elapsed Time: 2.02 seconds.
# Epoch:   8, Batch:    80, Avg. Loss: 0.0016197980 Elapsed Time: 2.01 seconds.
# Epoch:   8, Batch:    90, Avg. Loss: 0.0021919594 Elapsed Time: 2.01 seconds.
# Epoch:   8, Batch:   100, Avg. Loss: 0.0022626217 Elapsed Time: 2.07 seconds.
# Epoch:   8, Batch:   110, Avg. Loss: 0.0018539807 Elapsed Time: 2.01 seconds.
# Epoch:   8, Batch:   120, Avg. Loss: 0.0016253061 Elapsed Time: 1.97 seconds.
# Epoch:   8, Batch:   130, Avg. Loss: 0.0017968106 Elapsed Time: 2.0 seconds.
# Epoch:   8, Batch:   140, Avg. Loss: 0.0022083832 Elapsed Time: 1.9 seconds.
# Epoch:   8, Batch:   150, Avg. Loss: 0.0014394266 Elapsed Time: 1.92 seconds.
# Epoch:   8, Batch:   160, Avg. Loss: 0.0017459367 Elapsed Time: 1.91 seconds.
# Epoch:   8, Batch:   170, Avg. Loss: 0.0019432407 Elapsed Time: 1.97 seconds.
# Epoch:   8, Batch:   180, Avg. Loss: 0.0020355665 Elapsed Time: 2.02 seconds.
# Epoch:   8, Batch:   190, Avg. Loss: 0.0028733944 Elapsed Time: 1.94 seconds.
# Epoch:   8, Batch:   200, Avg. Loss: 0.0021635021 Elapsed Time: 1.94 seconds.
# Epoch:   8, Batch:   210, Avg. Loss: 0.0027533323 Elapsed Time: 2.01 seconds.
# Epoch:   8, Batch:   220, Avg. Loss: 0.0016018309 Elapsed Time: 1.96 seconds.
# Epoch:   8, Batch:   230, Avg. Loss: 0.0032764235 Elapsed Time: 1.94 seconds.
# Epoch:   8, Batch:   240, Avg. Loss: 0.0019537245 Elapsed Time: 1.99 seconds.
# Epoch:   8, Batch:   250, Avg. Loss: 0.0017166776 Elapsed Time: 1.98 seconds.
# Epoch:   8, Batch:   260, Avg. Loss: 0.0016216225 Elapsed Time: 2.14 seconds.
# Epoch:   8, Batch:   270, Avg. Loss: 0.0019346555 Elapsed Time: 2.11 seconds.
# Epoch:   8, Batch:   280, Avg. Loss: 0.0023878976 Elapsed Time: 2.08 seconds.
# Epoch:   8, Batch:   290, Avg. Loss: 0.0020089735 Elapsed Time: 2.13 seconds.
# Epoch:   8, Batch:   300, Avg. Loss: 0.0016810398 Elapsed Time: 2.16 seconds.
# Epoch:   8, Batch:   310, Avg. Loss: 0.0015263637 Elapsed Time: 2.06 seconds.
# Epoch:   8, Batch:   320, Avg. Loss: 0.0022224298 Elapsed Time: 2.08 seconds.
# Epoch:   8, Batch:   330, Avg. Loss: 0.0021842278 Elapsed Time: 1.98 seconds.
# Epoch:   8, Batch:   340, Avg. Loss: 0.0017020155 Elapsed Time: 2.03 seconds.
# Epoch:   9, Batch:    10, Avg. Loss: 0.0018829772 Elapsed Time: 26.7 seconds.
# Epoch:   9, Batch:    20, Avg. Loss: 0.0018850263 Elapsed Time: 2.1 seconds.
# Epoch:   9, Batch:    30, Avg. Loss: 0.0014752781 Elapsed Time: 2.04 seconds.
# Epoch:   9, Batch:    40, Avg. Loss: 0.0019519156 Elapsed Time: 2.0 seconds.
# Epoch:   9, Batch:    50, Avg. Loss: 0.0018696299 Elapsed Time: 2.08 seconds.
# Epoch:   9, Batch:    60, Avg. Loss: 0.0022189688 Elapsed Time: 2.13 seconds.
# Epoch:   9, Batch:    70, Avg. Loss: 0.0019619353 Elapsed Time: 2.16 seconds.
# Epoch:   9, Batch:    80, Avg. Loss: 0.0016388468 Elapsed Time: 2.19 seconds.
# Epoch:   9, Batch:    90, Avg. Loss: 0.0017311119 Elapsed Time: 2.09 seconds.
# Epoch:   9, Batch:   100, Avg. Loss: 0.0017005144 Elapsed Time: 1.92 seconds.
# Epoch:   9, Batch:   110, Avg. Loss: 0.0017379365 Elapsed Time: 1.98 seconds.
# Epoch:   9, Batch:   120, Avg. Loss: 0.0018715635 Elapsed Time: 1.99 seconds.
# Epoch:   9, Batch:   130, Avg. Loss: 0.0015946414 Elapsed Time: 2.12 seconds.
# Epoch:   9, Batch:   140, Avg. Loss: 0.0020064453 Elapsed Time: 2.13 seconds.
# Epoch:   9, Batch:   150, Avg. Loss: 0.0026400234 Elapsed Time: 2.17 seconds.
# Epoch:   9, Batch:   160, Avg. Loss: 0.0020721895 Elapsed Time: 2.12 seconds.
# Epoch:   9, Batch:   170, Avg. Loss: 0.0018021359 Elapsed Time: 1.99 seconds.
# Epoch:   9, Batch:   180, Avg. Loss: 0.0020602293 Elapsed Time: 1.92 seconds.
# Epoch:   9, Batch:   190, Avg. Loss: 0.0017474348 Elapsed Time: 1.86 seconds.
# Epoch:   9, Batch:   200, Avg. Loss: 0.0019936824 Elapsed Time: 1.84 seconds.
# Epoch:   9, Batch:   210, Avg. Loss: 0.0016907318 Elapsed Time: 1.84 seconds.
# Epoch:   9, Batch:   220, Avg. Loss: 0.0017931657 Elapsed Time: 2.07 seconds.
# Epoch:   9, Batch:   230, Avg. Loss: 0.0020377390 Elapsed Time: 2.18 seconds.
# Epoch:   9, Batch:   240, Avg. Loss: 0.0017307699 Elapsed Time: 2.32 seconds.
# Epoch:   9, Batch:   250, Avg. Loss: 0.0021938409 Elapsed Time: 2.19 seconds.
# Epoch:   9, Batch:   260, Avg. Loss: 0.0017807570 Elapsed Time: 2.18 seconds.
# Epoch:   9, Batch:   270, Avg. Loss: 0.0017632655 Elapsed Time: 2.05 seconds.
# Epoch:   9, Batch:   280, Avg. Loss: 0.0019301328 Elapsed Time: 2.04 seconds.
# Epoch:   9, Batch:   290, Avg. Loss: 0.0031562000 Elapsed Time: 2.06 seconds.
# Epoch:   9, Batch:   300, Avg. Loss: 0.0021965568 Elapsed Time: 1.96 seconds.
# Epoch:   9, Batch:   310, Avg. Loss: 0.0020269262 Elapsed Time: 1.91 seconds.
# Epoch:   9, Batch:   320, Avg. Loss: 0.0017386607 Elapsed Time: 2.17 seconds.
# Epoch:   9, Batch:   330, Avg. Loss: 0.0015124366 Elapsed Time: 1.99 seconds.
# Epoch:   9, Batch:   340, Avg. Loss: 0.0019033744 Elapsed Time: 2.1 seconds.
# Epoch:  10, Batch:    10, Avg. Loss: 0.0025873835 Elapsed Time: 28.0 seconds.
# Epoch:  10, Batch:    20, Avg. Loss: 0.0018751282 Elapsed Time: 2.17 seconds.
# Epoch:  10, Batch:    30, Avg. Loss: 0.0025094849 Elapsed Time: 2.9 seconds.
# Epoch:  10, Batch:    40, Avg. Loss: 0.0018265614 Elapsed Time: 2.55 seconds.
# Epoch:  10, Batch:    50, Avg. Loss: 0.0021178952 Elapsed Time: 2.26 seconds.
# Epoch:  10, Batch:    60, Avg. Loss: 0.0021286448 Elapsed Time: 2.25 seconds.
# Epoch:  10, Batch:    70, Avg. Loss: 0.0016304796 Elapsed Time: 2.8 seconds.
# Epoch:  10, Batch:    80, Avg. Loss: 0.0020967915 Elapsed Time: 2.46 seconds.
# Epoch:  10, Batch:    90, Avg. Loss: 0.0017803119 Elapsed Time: 2.35 seconds.
# Epoch:  10, Batch:   100, Avg. Loss: 0.0015845589 Elapsed Time: 2.57 seconds.
# Epoch:  10, Batch:   110, Avg. Loss: 0.0019282785 Elapsed Time: 2.13 seconds.
# Epoch:  10, Batch:   120, Avg. Loss: 0.0018855534 Elapsed Time: 2.18 seconds.
# Epoch:  10, Batch:   130, Avg. Loss: 0.0023863857 Elapsed Time: 2.19 seconds.
# Epoch:  10, Batch:   140, Avg. Loss: 0.0023147584 Elapsed Time: 2.13 seconds.
# Epoch:  10, Batch:   150, Avg. Loss: 0.0016682448 Elapsed Time: 2.11 seconds.
# Epoch:  10, Batch:   160, Avg. Loss: 0.0021215364 Elapsed Time: 2.06 seconds.
# Epoch:  10, Batch:   170, Avg. Loss: 0.0018832873 Elapsed Time: 2.13 seconds.
# Epoch:  10, Batch:   180, Avg. Loss: 0.0015207961 Elapsed Time: 2.44 seconds.
# Epoch:  10, Batch:   190, Avg. Loss: 0.0018222183 Elapsed Time: 2.59 seconds.
# Epoch:  10, Batch:   200, Avg. Loss: 0.0016849200 Elapsed Time: 2.11 seconds.
# Epoch:  10, Batch:   210, Avg. Loss: 0.0018554855 Elapsed Time: 2.12 seconds.
# Epoch:  10, Batch:   220, Avg. Loss: 0.0017329362 Elapsed Time: 2.19 seconds.
# Epoch:  10, Batch:   230, Avg. Loss: 0.0017080413 Elapsed Time: 2.11 seconds.
# Epoch:  10, Batch:   240, Avg. Loss: 0.0020371373 Elapsed Time: 2.07 seconds.
# Epoch:  10, Batch:   250, Avg. Loss: 0.0017376234 Elapsed Time: 2.02 seconds.
# Epoch:  10, Batch:   260, Avg. Loss: 0.0019418732 Elapsed Time: 1.97 seconds.
# Epoch:  10, Batch:   270, Avg. Loss: 0.0019884814 Elapsed Time: 1.93 seconds.
# Epoch:  10, Batch:   280, Avg. Loss: 0.0018105511 Elapsed Time: 1.96 seconds.
# Epoch:  10, Batch:   290, Avg. Loss: 0.0023866847 Elapsed Time: 1.95 seconds.
# Epoch:  10, Batch:   300, Avg. Loss: 0.0017643600 Elapsed Time: 1.94 seconds.
# Epoch:  10, Batch:   310, Avg. Loss: 0.0021215833 Elapsed Time: 1.88 seconds.
# Epoch:  10, Batch:   320, Avg. Loss: 0.0020291815 Elapsed Time: 1.89 seconds.
# Epoch:  10, Batch:   330, Avg. Loss: 0.0016923161 Elapsed Time: 1.93 seconds.
# Epoch:  10, Batch:   340, Avg. Loss: 0.0022857200 Elapsed Time: 1.91 seconds.
# Finished Training

# %% [markdown]
# # Plot the batch average loss

# %%
plt.plot(batch_loss)
plt.show()

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
net.to("cpu")
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
model_dir = data_root / "saved_models/"
model_name = data_root / "keypoints_model_1.pt"

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir / model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: This is a regresion problem, and we need to find the distance between the training and predicted keypoints. So I chose to use L1/L2 norms, namely `nn.L1Loss` and `nn.MSELoss`.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: I ended up using the the `NaimishNet` structure as described in the paper.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: Basically the more `n_epochs` we have the better model we get. So I set it to 100.
#
# After ploting the loss of all epochs, this is verified.
#
# For `batch_size`, what I've discovered is that, the bigger the batch is, the lesser iterations we will have during each epoch. I'm thinking this may make the model underfit.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.numpy()

filter_index = 0

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap="gray")
# Out:
# [[ 0.16518454 -0.2050423  -0.15196706  0.11481768 -0.01251574]
#  [-0.04991575  0.08576717 -0.11422628  0.15480968 -0.13697493]
#  [-0.19549973 -0.07517006 -0.02629449 -0.10973424 -0.18049556]
#  [-0.181273    0.18930884 -0.17996302  0.09894717  0.038645  ]
#  [-0.09688563 -0.06304047 -0.05935688  0.12255211  0.16369087]]
# (5, 5)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### Filter an image to see the effect of a convolutional kernel
# ---

# %%
## TODO: load in and display any image from the transformed test dataset
## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
import cv2

test_image = np.copy(test_images.numpy()[0].transpose(1, 2, 0).reshape(224, 224))

total_image_count = 7

plt.figure(figsize=(40, 30))

ax1 = plt.subplot(1, total_image_count, 1)
ax1.imshow(test_image, cmap="gray")
ax1.set_title("Original")

for i in range(total_image_count - 1):
    filtered = cv2.filter2D(test_image, -1, w[i][0])
    ax2 = plt.subplot(1, total_image_count, i + 2)
    ax2.imshow(filtered, cmap="gray")
    ax2.set_title("Filtered {}".format(i + 1))
plt.show()

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: I randomly chose the first 7 filters in the convolution layer to visualize. The first filter seems to be detecting the vertical edges, whereas the second one seems to be detecting the horizontal edges. Filter 4 seems to be detecting the intense area (white color) and the Filter 5 seems to be filppint the intensity and turn the image into a film.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
